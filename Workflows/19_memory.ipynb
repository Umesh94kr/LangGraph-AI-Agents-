# %% [markdown]
# #### **Memory in LLM**
#
# - LLMs are stateless
#
# - Context Window : Maximum number of input tokens that LLMs can take
# - In-Context-learning : LLM can use information given in prompt also in addition to its parametric knowledge
#
#
# ##### **Context Window Problem**
#
# Long conversation History -> Trimming + Summarization -> Hybrid Context -> LLM response
#
# ##### **Need new type of memory**
# (stable / re-usable / and useful)
#
# 1. Creation
# 2. Storage
# 3. Retrieval
# 4. Injection
